# %%
# Importing required Packages
import pandas as pd
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")
from IPython.display import Image

# %%
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

# %% [markdown]
# # Pivot Table

# %%
## Read data from below url and store into a variable named df
url ="https://raw.githubusercontent.com/SR1608/Pandas/main/students_marks.csv"

df = pd.read_csv(url)
df
# Out:
#    Student_name  Subject  Marks
# 0         Anand  English     50
# 1         Anand    Maths     41
# 2         Anand  Science     66
# 3        Avneet  English     89
# 4        Avneet    Maths     78
# 5        Avneet  Science     50
# 6      Chaitali  English     65
# 7      Chaitali    Maths     50
# 8      Chaitali  Science     60
# 9        Mukesh  English     73
# 10       Mukesh    Maths     76
# 11       Mukesh  Science     44
# 12         Neha  English     75
# 13         Neha    Maths     79
# 14         Neha  Science     49
# 15        Pooja  English     90
# 16        Pooja    Maths     44
# 17        Pooja  Science     71
# 18        Rahul  English     66
# 19        Rahul    Maths     59
# 20        Rahul  Science     63
# 21         Ravi  English     65
# 22         Ravi    Maths     83
# 23         Ravi  Science     86
# 24        Rohit  English     61
# 25        Rohit    Maths     48
# 26        Rohit  Science     58
# 27        Sagar  English     42
# 28        Sagar    Maths     63
# 29        Sagar  Science     92

# %% [markdown]
# ### Inputs Parameters<br><br>
#
# <li><b>Data :</b> Dataframe <br>
# <li><b>index :</b> Key<br>
# <li><b>Columns :</b> Header<br>
# <li><b>Values :</b> Column name to be used to fill values in the value<br>
# <li><b>aggfunc :</b> Function to be used e.g. mean,sum,median etc<br>

# %%
df_pivot = pd.pivot_table(df,
                index='Student_name',
              columns='Subject',
              values ='Marks')
df_pivot
# Out:
# Subject       English  Maths  Science
# Student_name
# Anand              50     41       66
# Avneet             89     78       50
# Chaitali           65     50       60
# Mukesh             73     76       44
# Neha               75     79       49
# Pooja              90     44       71
# Rahul              66     59       63
# Ravi               65     83       86
# Rohit              61     48       58
# Sagar              42     63       92

# %%
Image('pivot.png')

# %%
## Read data from below url and store into a variable named df
url = 'https://raw.githubusercontent.com/edyoda/data-science-complete-tutorial/master/Data/gapminder-FiveYearData.csv'

df=pd.read_csv(url)

# %%
df
# Out:
#           country  year         pop continent  lifeExp   gdpPercap
# 0     Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1     Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2     Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3     Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4     Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# ...           ...   ...         ...       ...      ...         ...
# 1699     Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700     Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701     Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702     Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703     Zimbabwe  2007  12311143.0    Africa   43.487  469.709298
#
# [1704 rows x 6 columns]

# %% [markdown]
# ### Create a pivot table with country as index,year as columns and fill the table with life exp as values

# %%
pd.pivot_table(df,
              index='country',
              columns='year',
              values='lifeExp')
# Out:
# year                  1952    1957    1962    1967    1972    1977    1982  \
# country
# Afghanistan         28.801  30.332  31.997  34.020  36.088  38.438  39.854
# Albania             55.230  59.280  64.820  66.220  67.690  68.930  70.420
# Algeria             43.077  45.685  48.303  51.407  54.518  58.014  61.368
# Angola              30.015  31.999  34.000  35.985  37.928  39.483  39.942
# Argentina           62.485  64.399  65.142  65.634  67.065  68.481  69.942
# ...                    ...     ...     ...     ...     ...     ...     ...
# Vietnam             40.412  42.887  45.363  47.838  50.254  55.764  58.816
# West Bank and Gaza  43.160  45.671  48.127  51.631  56.532  60.765  64.406
# Yemen Rep.          32.548  33.970  35.180  36.984  39.848  44.175  49.113
# Zambia              42.038  44.077  46.023  47.768  50.107  51.386  51.821
# Zimbabwe            48.451  50.469  52.358  53.995  55.635  57.674  60.363
#
# year                  1987    1992    1997    2002    2007
# country
# Afghanistan         40.822  41.674  41.763  42.129  43.828
# Albania             72.000  71.581  72.950  75.651  76.423
# Algeria             65.799  67.744  69.152  70.994  72.301
# Angola              39.906  40.647  40.963  41.003  42.731
# Argentina           70.774  71.868  73.275  74.340  75.320
# ...                    ...     ...     ...     ...     ...
# Vietnam             62.820  67.662  70.672  73.017  74.249
# West Bank and Gaza  67.046  69.718  71.096  72.370  73.422
# Yemen Rep.          52.922  55.599  58.020  60.308  62.698
# Zambia              50.821  46.100  40.238  39.193  42.384
# Zimbabwe            62.351  60.377  46.809  39.989  43.487
#
# [142 rows x 12 columns]

# %% [markdown]
# ### Create a pivot table with continent as index,year as columns and fill the table with pop as values

# %%
pd.pivot_table(df,
              index='continent',
              columns='year',
              values='pop',
              aggfunc=np.min)
# Out:
#               gdpPercap                                            \
# year               1952          1957          1962          1967
# continent
# Africa       298.846212    335.997115    355.203227    412.977514
# Americas    1397.717137   1544.402995   1662.137359   1452.057666
# Asia         331.000000    350.000000    388.000000    349.000000
# Europe       973.533195   1353.989176   1709.683679   2172.352423
# Oceania    10039.595640  10949.649590  12217.226860  14463.918930
#
#                                                                    \
# year               1972          1977          1982          1987
# continent
# Africa       464.099504    502.319733    462.211415    389.876185
# Americas    1654.456946   1874.298931   2011.159549   1823.015995
# Asia         357.000000    371.000000    424.000000    385.000000
# Europe      2860.169750   3528.481305   3630.880722   3738.932735
# Oceania    16046.037280  16233.717700  17632.410400  19007.191290
#
#                                        ...        pop                        \
# year               1992          1997  ...       1962       1967       1972
# continent                              ...
# Africa       410.896824    312.188423  ...    65345.0    70787.0    76595.0
# Americas    1456.309517   1341.726931  ...   887498.0   960155.0   975199.0
# Asia         347.000000    415.000000  ...   171863.0   202182.0   230800.0
# Europe      2497.437901   3193.054604  ...   182053.0   198676.0   209275.0
# Oceania    18363.324940  21050.413770  ...  2488550.0  2728150.0  2929100.0
#
#                                                                              \
# year            1977       1982       1987       1992       1997       2002
# continent
# Africa       86796.0    98593.0   110812.0   125911.0   145608.0   170372.0
# Americas   1039009.0  1116479.0  1191336.0  1183669.0  1138101.0  1101832.0
# Asia        297410.0   377967.0   454612.0   529491.0   598561.0   656397.0
# Europe      221823.0   233997.0   244676.0   259012.0   271192.0   288030.0
# Oceania    3164900.0  3210650.0  3317166.0  3437674.0  3676187.0  3908037.0
#
#
# year            2007
# continent
# Africa      199579.0
# Americas   1056608.0
# Asia        708573.0
# Europe      301931.0
# Oceania    4115771.0
#
# [5 rows x 24 columns]

# %% [markdown]
# # Stacking & Unstacking

# %% [markdown]
# ## Stack
#
# Stack() Function in dataframe stacks the column to rows at level 1 (default).

# %%
Image('stack.png')

# %%
df_stack = df_pivot.stack()
df_stack
# Out:
# Student_name  Subject
# Anand         English    50
#               Maths      41
#               Science    66
# Avneet        English    89
#               Maths      78
#               Science    50
# Chaitali      English    65
#               Maths      50
#               Science    60
# Mukesh        English    73
#               Maths      76
#               Science    44
# Neha          English    75
#               Maths      79
#               Science    49
# Pooja         English    90
#               Maths      44
#               Science    71
# Rahul         English    66
#               Maths      59
#               Science    63
# Ravi          English    65
#               Maths      83
#               Science    86
# Rohit         English    61
#               Maths      48
#               Science    58
# Sagar         English    42
#               Maths      63
#               Science    92
# dtype: int64

# %% [markdown]
# ## Unstack
# unstack() Function in dataframe unstacks the row to columns . Basically it’s a reverse of stacking

# %%
Image("unstack.png")

# %%
df_stack.unstack()
# Out:
# Subject       English  Maths  Science
# Student_name
# Anand              50     41       66
# Avneet             89     78       50
# Chaitali           65     50       60
# Mukesh             73     76       44
# Neha               75     79       49
# Pooja              90     44       71
# Rahul              66     59       63
# Ravi               65     83       86
# Rohit              61     48       58
# Sagar              42     63       92

# %% [markdown]
# #  Date Parameter

# %%
## Read data from below url and store into a variable named df
url ='https://raw.githubusercontent.com/SR1608/Pandas/main/students_dob.csv'
df = pd.read_csv(url)
df
# Out:
#   first_name last_name date_of_birth
# 0       John       Doe      23/08/96
# 1       Jane     Smith      02/04/95
# 2      Sarah    Thomas      17/01/90
# 3      Frank     Brown      25/12/88
# 4       Mike     Davis      12/06/93
# 5   Jennifer    Wilson      28/03/91
# 6    Jessica    Garcia      01/05/93
# 7       Fred     Clark      13/09/85
# 8        Bob     Lopez      04/06/87

# %%
df.dtypes
# Out:
# first_name       object
# last_name        object
# date_of_birth    object
# dtype: object

# %%
df['date_of_birth'] = pd.to_datetime(df['date_of_birth'])

# %%
df.dtypes
# Out:
# first_name               object
# last_name                object
# date_of_birth    datetime64[ns]
# dtype: object

# %% [markdown]
# ### Extract year,month,days from DOB

# %%
df['year'] = df['date_of_birth'].dt.year
df['month'] = df['date_of_birth'].dt.month
df['date'] = df['date_of_birth'].dt.day

# %%
df.head()
# Out:
#   first_name last_name date_of_birth  year  month  date
# 0       John       Doe    1996-08-23  1996      8    23
# 1       Jane     Smith    1995-02-04  1995      2     4
# 2      Sarah    Thomas    1990-01-17  1990      1    17
# 3      Frank     Brown    1988-12-25  1988     12    25
# 4       Mike     Davis    1993-12-06  1993     12     6

# %% [markdown]
# ### Calculate Age of each student

# %%
df['age'] = ((pd.Timestamp.now() - df['date_of_birth']).dt.days /365).astype('int')

# %%
df.head()
# Out:
#   first_name last_name date_of_birth  year  month  date  age
# 0       John       Doe    1996-08-23  1996      8    23   24
# 1       Jane     Smith    1995-02-04  1995      2     4   25
# 2      Sarah    Thomas    1990-01-17  1990      1    17   30
# 3      Frank     Brown    1988-12-25  1988     12    25   31
# 4       Mike     Davis    1993-12-06  1993     12     6   26

# %% [markdown]
# # Bonus

# %%
from pandasgui import show
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
show(df)
# Out:
# PandasGUI ERROR — pandasgui.store — EOL while scanning string literal (<unknown>, line 1)
# Traceback (most recent call last):
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandasgui/store.py", line 199, in apply_filters
#     df = df.query(filt.expr)
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py", line 3338, in query
#     res = self.eval(expr, **kwargs)
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py", line 3468, in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/computation/eval.py", line 341, in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/computation/expr.py", line 787, in __init__
#     self.terms = self.parse()
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/computation/expr.py", line 806, in parse
#     return self._visitor.visit(self.expr)
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/computation/expr.py", line 394, in visit
#     raise e
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/computation/expr.py", line 390, in visit
#     node = ast.fix_missing_locations(ast.parse(clean))
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/ast.py", line 35, in parse
#     return compile(source, filename, mode, PyCF_ONLY_AST)
#   File "<unknown>", line 1
#     Married = 'yes
#                   ^
# SyntaxError: EOL while scanning string literal
# PandasGUI ERROR — pandasgui.store — cannot assign without a target object
# Traceback (most recent call last):
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandasgui/store.py", line 199, in apply_filters
#     df = df.query(filt.expr)
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py", line 3338, in query
#     res = self.eval(expr, **kwargs)
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py", line 3468, in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/computation/eval.py", line 341, in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/computation/expr.py", line 787, in __init__
#     self.terms = self.parse()
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/computation/expr.py", line 806, in parse
#     return self._visitor.visit(self.expr)
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/computation/expr.py", line 398, in visit
#     return visitor(node, **kwargs)
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/computation/expr.py", line 404, in visit_Module
#     return self.visit(expr, **kwargs)
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/computation/expr.py", line 398, in visit
#     return visitor(node, **kwargs)
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/computation/expr.py", line 607, in visit_Assign
#     raise ValueError("cannot assign without a target object")
# ValueError: cannot assign without a target object
# PandasGUI ERROR — pandasgui.store — cannot assign without a target object
# Traceback (most recent call last):
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandasgui/store.py", line 199, in apply_filters
#     df = df.query(filt.expr)
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py", line 3338, in query
#     res = self.eval(expr, **kwargs)
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py", line 3468, in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/computation/eval.py", line 341, in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/computation/expr.py", line 787, in __init__
#     self.terms = self.parse()
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/computation/expr.py", line 806, in parse
#     return self._visitor.visit(self.expr)
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/computation/expr.py", line 398, in visit
#     return visitor(node, **kwargs)
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/computation/expr.py", line 404, in visit_Module
#     return self.visit(expr, **kwargs)
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/computation/expr.py", line 398, in visit
#     return visitor(node, **kwargs)
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/computation/expr.py", line 607, in visit_Assign
#     raise ValueError("cannot assign without a target object")
# ValueError: cannot assign without a target object
# PandasGUI ERROR — pandasgui.store — can't assign to literal (<unknown>, line 1)
# Traceback (most recent call last):
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandasgui/store.py", line 199, in apply_filters
#     df = df.query(filt.expr)
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py", line 3338, in query
#     res = self.eval(expr, **kwargs)
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py", line 3468, in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/computation/eval.py", line 341, in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/computation/expr.py", line 787, in __init__
#     self.terms = self.parse()
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/computation/expr.py", line 806, in parse
#     return self._visitor.visit(self.expr)
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/computation/expr.py", line 394, in visit
#     raise e
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/computation/expr.py", line 390, in visit
#     node = ast.fix_missing_locations(ast.parse(clean))
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/ast.py", line 35, in parse
#     return compile(source, filename, mode, PyCF_ONLY_AST)
#   File "<unknown>", line 1
# SyntaxError: can't assign to literal
# PandasGUI ERROR — pandasgui.store — EOL while scanning string literal (<unknown>, line 1)
# Traceback (most recent call last):
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandasgui/store.py", line 199, in apply_filters
#     df = df.query(filt.expr)
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py", line 3338, in query
#     res = self.eval(expr, **kwargs)
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py", line 3468, in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/computation/eval.py", line 341, in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/computation/expr.py", line 787, in __init__
#     self.terms = self.parse()
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/computation/expr.py", line 806, in parse
#     return self._visitor.visit(self.expr)
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/computation/expr.py", line 394, in visit
#     raise e
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/computation/expr.py", line 390, in visit
#     node = ast.fix_missing_locations(ast.parse(clean))
#   File "/Users/e106922/opt/anaconda3/envs/py36/lib/python3.6/ast.py", line 35, in parse
#     return compile(source, filename, mode, PyCF_ONLY_AST)
#   File "<unknown>", line 1
#     Married == 'Yes
#                    ^
# SyntaxError: EOL while scanning string literal
